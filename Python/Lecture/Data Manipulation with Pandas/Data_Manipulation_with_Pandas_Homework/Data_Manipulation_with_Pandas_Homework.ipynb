# %% [markdown]
# # Homework

# %% [markdown]
# ### Problem 1
# In this question, we will use the csv file **Temp.csv**.
# - Read it into a data frame, call it `Temp`.

# %%
#### Your code here
import pandas as pd

df = pd.read_csv('Temp.csv')
df
# Out:
#          City        State  Temperature
# 0         NYC     New York           67
# 1      Albany     New York           49
# 2     Buffalo     New York           38
# 3    Hartford  Connecticut           63
# 4  Bridgeport  Connecticut           58
# 5      Treton   New Jersey           72
# 6      Newark   New Jersey           68

# %% [markdown]
# - We learned that the temperature at New Haven, Connecticut is currently 58 degree fahrenheit. Add this information into the DataFrame.

# %%
df2 = pd.DataFrame([['New Haven','Connecticut',58]],columns=['City','State','Temperature'])
df2
# Out:
#         City        State  Temperature
# 0  New Haven  Connecticut           58

# %%
df3 = df.append(df2)

# %% [markdown]
# - Replace the names of the states by their abbreviations. That is
#     - Connecticut --> CT
#     - New Jersey  --> NJ
#     - New York    --> NY

# %%
#### Your code here
df3 = df3.replace('Connecticut','CT').replace('New Jersey','NJ').replace('New York','NY')

# %%
df3
# Out:
#          City State  Temperature
# 0         NYC    NY           67
# 1      Albany    NY           49
# 2     Buffalo    NY           38
# 3    Hartford    CT           63
# 4  Bridgeport    CT           58
# 5      Treton    NJ           72
# 6      Newark    NJ           68
# 0   New Haven    CT           58

# %% [markdown]
# - Select the rows in New York.

# %% [markdown]
# - What is the average of the temperature of cities in NY?

# %%
NYC = (df3.loc[df3['State'] == 'NY']).mean()

# %%
NYC
# Out:
# Temperature    51.333333
# dtype: float64

# %% [markdown]
# - Find the mean and the standard deviation of the temperature of each state.

# %%
#### Your code here
states = df3.groupby('State')
print(states.mean(),'\n\n', states.std())
# Out:
#        Temperature
# State
# CT       59.666667
# NJ       70.000000
# NY       51.333333
#
#         Temperature
# State
# CT        2.886751
# NJ        2.828427
# NY       14.640128

# %% [markdown]
# - We know the capital of each state:
#     - Connecticut --> Hartford
#     - New Jersey  --> Treton
#     - New York    --> Albany
#
#     Create a data frame, `Capital`, with two columns: State and Capital, which should look like:
#
# || State| Capital|
# | :-: |:---: | :---:|
# | 0| CT  | Hartford|
# | 1| NJ | Treton|
# | 2| NY| Albany|

# %%
#### Your code here
Capital = \
pd.DataFrame([['Connecticut','Hartford'],['New Jersey','Treton'],['New York','Albany']]
             ,columns = ['State', 'Capital'])
Capital
# Out:
#          State   Capital
# 0  Connecticut  Hartford
# 1   New Jersey    Treton
# 2     New York    Albany

# %% [markdown]
# - Mutate a new boolean column, `Capital`, to `Temp`, which is `True` if the city in the row is the capital of the state, else `False`.

# %%
#### Your code here
# Out:
#          City State  Temperature Capital
# 0         NYC    NY           67   False
# 1      Albany    NY           49    True
# 2     Buffalo    NY           38   False
# 3    Hartford    CT           63    True
# 4  Bridgeport    CT           58   False
# 5   New Haven    CT           58   False
# 6      Treton    NJ           72    True
# 7      Newark    NJ           68   False

# %% [markdown]
# ### Problem 2
#
# - a. Load the Gross Domestic Product data for the 190 ranked countries in the file **GDP.csv**. Load **Country.csv** into a DataFrame.
# - b. Match the data based on the country shortcode. How many of the IDs match?
# - c. Sort the data frame in descending order by GDP rank. What is the 13th country in the resulting data frame? (Note: GDP formats as 123,456,789.)
# - d. What is the average GDP for the "High income: OECD" and "High income: nonOECD" group?
# - e. What is the average GDP for different income groups and regions?

# %%
#### Your code here
# (a)
import numpy as np
import pandas as pd
gdp = pd.read_csv('GDP.csv', skiprows=range(5), header= None, usecols=[0,1,3,4], nrows=190, encoding='ISO-8859-1')
gdp.columns = ['CountryCode', 'Rank', 'CountryName', 'GDP']
country = pd.read_csv('Country.csv', encoding='ISO-8859-1')

# %%
# (b)
gdp_detail = country.merge(gdp,on = 'CountryCode', how = 'inner')
#gdp.CountryCode
gdp_detail.CountryCode.count()
# Out:
# 189

# %%
# (c)
#gdp_detail['GDP'] = (gdp_detail['GDP'].str.split()).apply(lambda x: float(x[0].replace(',', '')))
sorted_gdp = gdp_detail.sort_values('Rank', ascending=False)
sorted_gdp[12:13].CountryCode
# Out:
# 68    GRD
# Name: CountryCode, dtype: object

# %%
# (d)

#income_groups = gdp_detail[]
#gdp_detail.groupby('Income Group').agg({'GDP':'mean'})
gdp_detail[gdp_detail['Income Group']=='High income: nonOECD']
# Out:
#     CountryCode                                          Long Name  \
# 0           ABW                                              Aruba
# 4           ARE                               United Arab Emirates
# 17          BHR                                 Kingdom of Bahrain
# 18          BHS                        Commonwealth of The Bahamas
# 22          BMU                                       The Bermudas
# 25          BRB                                           Barbados
# 26          BRN                                  Brunei Darussalam
# 42          CYP                                 Republic of Cyprus
# 53          EST                                Republic of Estonia
# 66          GNQ                      Republic of Equatorial Guinea
# 71          HKG  Hong Kong Special Administrative Region of the...
# 73          HRV                                Republic of Croatia
# 95          KWT                                    State of Kuwait
# 104         LVA                                 Republic of Latvia
# 105         MAC  Macao Special Administrative Region of the Peo...
# 107         MCO                             Principality of Monaco
# 115         MLT                                  Republic of Malta
# 131         OMN                                  Sultanate of Oman
# 139         PRI                                        Puerto Rico
# 142         QAT                                     State of Qatar
# 146         SAU                            Kingdom of Saudi Arabia
# 149         SGP                              Republic of Singapore
# 169         TTO                    Republic of Trinidad and Tobago
#
#              Income Group                      Region Lending category  \
# 0    High income: nonOECD   Latin America & Caribbean              NaN
# 4    High income: nonOECD  Middle East & North Africa              NaN
# 17   High income: nonOECD  Middle East & North Africa              NaN
# 18   High income: nonOECD   Latin America & Caribbean              NaN
# 22   High income: nonOECD               North America              NaN
# 25   High income: nonOECD   Latin America & Caribbean              NaN
# 26   High income: nonOECD         East Asia & Pacific              NaN
# 42   High income: nonOECD       Europe & Central Asia              NaN
# 53   High income: nonOECD       Europe & Central Asia              NaN
# 66   High income: nonOECD          Sub-Saharan Africa             IBRD
# 71   High income: nonOECD         East Asia & Pacific              NaN
# 73   High income: nonOECD       Europe & Central Asia             IBRD
# 95   High income: nonOECD  Middle East & North Africa              NaN
# 104  High income: nonOECD       Europe & Central Asia              NaN
# 105  High income: nonOECD         East Asia & Pacific              NaN
# 107  High income: nonOECD       Europe & Central Asia              NaN
# 115  High income: nonOECD  Middle East & North Africa              NaN
# 131  High income: nonOECD  Middle East & North Africa              NaN
# 139  High income: nonOECD   Latin America & Caribbean              NaN
# 142  High income: nonOECD  Middle East & North Africa              NaN
# 146  High income: nonOECD  Middle East & North Africa              NaN
# 149  High income: nonOECD         East Asia & Pacific              NaN
# 169  High income: nonOECD   Latin America & Caribbean             IBRD
#
#     Other groups                         Currency Unit  \
# 0            NaN                         Aruban florin
# 4            NaN                         U.A.E. dirham
# 17           NaN                        Bahraini dinar
# 18           NaN                       Bahamian dollar
# 22           NaN                        Bermuda dollar
# 25           NaN                       Barbados dollar
# 26           NaN                         Brunei dollar
# 42     Euro area                                  Euro
# 53           NaN                        Estonian kroon
# 66           NaN                             CFA franc
# 71           NaN                      Hong Kong dollar
# 73           NaN                         Croatian kuna
# 95           NaN                         Kuwaiti dinar
# 104          NaN                          Latvian lats
# 105          NaN                          Macao pataca
# 107          NaN                                  Euro
# 115    Euro area  Euro (data reported in Maltese liri)
# 131          NaN                            Rial Omani
# 139          NaN                           U.S. dollar
# 142          NaN                          Qatari riyal
# 146          NaN                   Saudi Arabian riyal
# 149          NaN                      Singapore dollar
# 169          NaN            Trinidad and Tobago dollar
#
#     Latest population census   Latest household survey  \
# 0                       2000                       NaN
# 4                       2005                       NaN
# 17                      2001                       NaN
# 18                      2000                       NaN
# 22                      2000                       NaN
# 25                      2000                       NaN
# 26                      2001                       NaN
# 42                      2001                       NaN
# 53                      2000                       NaN
# 66                      2002                       NaN
# 71                      2006                       NaN
# 73                      2001                       NaN
# 95                      2005                 FHS, 1996
# 104                     2000                       NaN
# 105                     2006                       NaN
# 107                     2008                       NaN
# 115                     2005                       NaN
# 131                     2003                 FHS, 1995
# 139                     2000              RHS, 1995/96
# 142                     2004                       NaN
# 146                     2004  Demographic survey, 2007
# 149                     2000  General  household, 2005
# 169                     2000                MICS, 2006
#
#                                          Special Notes  ...  \
# 0                                                  NaN  ...
# 4                                                  NaN  ...
# 17                                                 NaN  ...
# 18   The government has revised national accounts d...  ...
# 22   The Statistical Office has revised national ac...  ...
# 25                                                 NaN  ...
# 26                                                 NaN  ...
# 42   A simple multiplier is used to convert the nat...  ...
# 53                                                 NaN  ...
# 66                                                 NaN  ...
# 71   On 1 July 1997 China resumed its exercise of s...  ...
# 73   The Statistical Bureau has revised main GDP ag...  ...
# 95   Fiscal year end: June 30; reporting period for...  ...
# 104                                                NaN  ...
# 105  On 20 December 1999 China resumed its exercise...  ...
# 107                                                NaN  ...
# 115                                                NaN  ...
# 131                                                NaN  ...
# 139  Fiscal year end: June 30; reporting period for...  ...
# 142                                                NaN  ...
# 146                                                NaN  ...
# 149  Fiscal year end: March 31; reporting period fo...  ...
# 169                                                NaN  ...
#
#     Latest industrial data  Latest trade data  Latest water withdrawal data  \
# 0                      NaN             2008.0                           NaN
# 4                      NaN             2008.0                        2005.0
# 17                     NaN             2007.0                        2003.0
# 18                  1997.0             2008.0                           NaN
# 22                     NaN             2008.0                           NaN
# 25                     NaN             2008.0                        2000.0
# 26                     NaN             2006.0                           NaN
# 42                  2005.0             2008.0                        2000.0
# 53                  2005.0             2008.0                        2000.0
# 66                     NaN                NaN                        2000.0
# 71                     NaN             2008.0                           NaN
# 73                     NaN             2008.0                           NaN
# 95                     NaN             2007.0                        2002.0
# 104                 2005.0             2008.0                        2000.0
# 105                    NaN             2008.0                           NaN
# 107                    NaN                NaN                           NaN
# 115                 2004.0             2008.0                        2000.0
# 131                 2005.0             2008.0                        2003.0
# 139                    NaN                NaN                           NaN
# 142                 2005.0             2008.0                        2005.0
# 146                 2005.0             2007.0                        2006.0
# 149                 2005.0             2008.0                           NaN
# 169                 2005.0             2008.0                        2000.0
#
#     2-alpha code WB-2 code            Table Name            Short Name Rank  \
# 0             AW        AW                 Aruba                 Aruba  161
# 4             AE        AE  United Arab Emirates  United Arab Emirates   32
# 17            BH        BH               Bahrain               Bahrain   93
# 18            BS        BS          Bahamas, The           The Bahamas  138
# 22            BM        BM               Bermuda               Bermuda  149
# 25            BB        BB              Barbados              Barbados  153
# 26            BN        BN     Brunei Darussalam                Brunei  113
# 42            CY        CY                Cyprus                Cyprus  102
# 53            EE        EE               Estonia               Estonia  103
# 66            GQ        GQ     Equatorial Guinea     Equatorial Guinea  110
# 71            HK        HK  Hong Kong SAR, China  Hong Kong SAR, China   37
# 73            HR        HR               Croatia               Croatia   71
# 95            KW        KW                Kuwait                Kuwait   56
# 104           LV        LV                Latvia                Latvia   94
# 105           MO        MO      Macao SAR, China      Macao SAR, China   82
# 107           MC        MC                Monaco                Monaco  147
# 115           MT        MT                 Malta                 Malta  137
# 131           OM        OM                  Oman                  Oman   66
# 139           PR        PR           Puerto Rico           Puerto Rico   61
# 142           QA        QA                 Qatar                 Qatar   54
# 146           SA        SA          Saudi Arabia          Saudi Arabia   19
# 149           SG        SG             Singapore             Singapore   35
# 169           TT        TT   Trinidad and Tobago   Trinidad and Tobago  101
#
#               CountryName        GDP
# 0                   Aruba     2,584
# 4    United Arab Emirates   348,595
# 17                Bahrain    29,044
# 18           Bahamas, The     8,149
# 22                Bermuda     5,474
# 25               Barbados     4,225
# 26      Brunei Darussalam    16,954
# 42                 Cyprus    22,767
# 53                Estonia    22,390
# 66      Equatorial Guinea    17,697
# 71   Hong Kong SAR, China   263,259
# 73                Croatia    59,228
# 95                 Kuwait   160,913
# 104                Latvia    28,373
# 105      Macao SAR, China    43,582
# 107                Monaco     6,075
# 115                 Malta     8,722
# 131                  Oman    69,972
# 139           Puerto Rico   101,496
# 142                 Qatar   171,476
# 146          Saudi Arabia   711,050
# 149             Singapore   274,701
# 169   Trinidad and Tobago    23,320
#
# [23 rows x 34 columns]

# %%
# (e)
# Out:
#                                                             GDP
# Income Group         Region
# High income: OECD    East Asia & Pacific         2197267.750000
#                      Europe & Central Asia        756704.434783
#                      Middle East & North Africa   258217.000000
#                      North America               9033012.000000
# High income: nonOECD East Asia & Pacific          149624.000000
#                      Europe & Central Asia         27766.600000
#                      Latin America & Caribbean     27954.800000
#                      Middle East & North Africa   214253.142857
#                      North America                  5474.000000
#                      Sub-Saharan Africa            17697.000000
